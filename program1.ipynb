# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammed-Alif1/innomaitcs/blob/main/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %%
n=17
if n%2 != 0:
    print("weird")
elif 2<=n<=5 :
    print("Not Weird")
elif 6<=n<=20:
    print("weird")
else:
    print("Not Weird")
# Out:
# weird

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)
# Out:
# 3
# 5
# 8
# -2
# 15

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
# 3
# 6
# 0
# 0.5

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i*i)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %%
def is_leap(year):
    leap = False
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True
    else:
        leap = False
    return leap

year = int(input())
print(is_leap(year))
# Out:
# 2000
# True

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(1, n + 1):
        print(i, end="")
# Out:
# 5
# 12345
